# %% [markdown]
# ### Домашняя работа №1

# %% [markdown]
# #### 1. Пользователь в бесконечном цикле вводит числа через консоль до тех пор, пока не введёт что-то, отличное от числа (после этого цикл завершается). В конце программа должна вывести сумму всех введённых чисел.

# %%
sum = 0
while True:
    number = input('Enter any number : ')
    try:
        sum += float(number)
        print(f'Number entered = {number}')
    except ValueError:
        break
print(f'Sum of the entered numbers = {sum}')
# Out:
# Number entered = 4
# Number entered = 95
# Number entered = -524
# Number entered = 854
# Number entered = 50.548
# Sum of the entered numbers = 479.548

# %% [markdown]
# #### 2. Пользователь вводит строку через консоль (состоящую только из букв в разном регистре). Программа должна создать новую строку, содержащую только те буквы из исходной строки, которые были в верхнем регистре.

# %%
upper_letter = []
text = input('Enter your letters : ')
print(f'Entered your letters :{text}')
for letter in text:
    if letter.isupper():
        upper_letter.append(letter)
print(f'Entered upper letters :{upper_letter}')
# Out:
# Entered your letters :jbfLKvKNNLKknckanjbwgipxpxPm
# Entered upper letters :['L', 'K', 'K', 'N', 'N', 'L', 'K', 'P']

# %% [markdown]
# #### 3. Классическая игра FizzBuzz. Программа в цикле выводит в консоль числа от 1 до 100. Если число кратно 3, вместо него выводится Fizz. Если кратно 5 — Buzz. Если кратно и 3, и 5 — FizzBuzz.

# %%
for i in range(0, 101):
    if i % 3 == 0 and i % 5 == 0:
        print(f'Number = {i}, FizzBuzz')
    elif i % 3 == 0:
        print(f'Number = {i}, Fizz')
    elif i % 5 == 0:
        print(f'Number = {i}, Buzz')
    else:
        print(f'Number = {i}')
# Out:
# Number = 0, FizzBuzz
# Number = 1
# Number = 2
# Number = 3, Fizz
# Number = 4
# Number = 5, Buzz
# Number = 6, Fizz
# Number = 7
# Number = 8
# Number = 9, Fizz
# Number = 10, Buzz
# Number = 11
# Number = 12, Fizz
# Number = 13
# Number = 14
# Number = 15, FizzBuzz
# Number = 16
# Number = 17
# Number = 18, Fizz
# Number = 19
# Number = 20, Buzz
# Number = 21, Fizz
# Number = 22
# Number = 23
# Number = 24, Fizz
# Number = 25, Buzz
# Number = 26
# Number = 27, Fizz
# Number = 28
# Number = 29
# Number = 30, FizzBuzz
# Number = 31
# Number = 32
# Number = 33, Fizz
# Number = 34
# Number = 35, Buzz
# Number = 36, Fizz
# Number = 37
# Number = 38
# Number = 39, Fizz
# Number = 40, Buzz
# Number = 41
# Number = 42, Fizz
# Number = 43
# Number = 44
# Number = 45, FizzBuzz
# Number = 46
# Number = 47
# Number = 48, Fizz
# Number = 49
# Number = 50, Buzz
# Number = 51, Fizz
# Number = 52
# Number = 53
# Number = 54, Fizz
# Number = 55, Buzz
# Number = 56
# Number = 57, Fizz
# Number = 58
# Number = 59
# Number = 60, FizzBuzz
# Number = 61
# Number = 62
# Number = 63, Fizz
# Number = 64
# Number = 65, Buzz
# Number = 66, Fizz
# Number = 67
# Number = 68
# Number = 69, Fizz
# Number = 70, Buzz
# Number = 71
# Number = 72, Fizz
# Number = 73
# Number = 74
# Number = 75, FizzBuzz
# Number = 76
# Number = 77
# Number = 78, Fizz
# Number = 79
# Number = 80, Buzz
# Number = 81, Fizz
# Number = 82
# Number = 83
# Number = 84, Fizz
# Number = 85, Buzz
# Number = 86
# Number = 87, Fizz
# Number = 88
# Number = 89
# Number = 90, FizzBuzz
# Number = 91
# Number = 92
# Number = 93, Fizz
# Number = 94
# Number = 95, Buzz
# Number = 96, Fizz
# Number = 97
# Number = 98
# Number = 99, Fizz
# Number = 100, Buzz
